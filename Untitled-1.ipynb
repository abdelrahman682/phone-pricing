# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("phone_data.csv")
df.head()
# Out:
#    m                            Name    Brand                   Model  \
# 0  0  OnePlus 7T Pro McLaren Edition  OnePlus  7T Pro McLaren Edition
# 1  1                   Realme X2 Pro   Realme                  X2 Pro
# 2  2               iPhone 11 Pro Max    Apple       iPhone 11 Pro Max
# 3  3                       iPhone 11    Apple               iPhone 11
# 4  4                    LG G8X ThinQ       LG               G8X ThinQ
#
#    Battery capacity (mAh)  Screen size (inches) Touchscreen  Resolution x  \
# 0                    4085                  6.67         Yes          1440
# 1                    4000                  6.50         Yes          1080
# 2                    3969                  6.50         Yes          1242
# 3                    3110                  6.10         Yes           828
# 4                    4000                  6.40         Yes          1080
#
#    Resolution y  Processor  ...  Rear camera  Front camera  Operating system  \
# ...

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(" ", "_")
for i in df.columns:
    if df[i].dtype == "object":
        df[i] = df[i].str.lower()
        df[i] = df[i].str.replace(" ", "_")
df
# Out:
#          m                            name     brand                   model  \
# 0        0  oneplus_7t_pro_mclaren_edition   oneplus  7t_pro_mclaren_edition
# 1        1                   realme_x2_pro    realme                  x2_pro
# 2        2               iphone_11_pro_max     apple       iphone_11_pro_max
# 3        3                       iphone_11     apple               iphone_11
# 4        4                    lg_g8x_thinq        lg               g8x_thinq
# ...    ...                             ...       ...                     ...
# 1354  1354                   intex_aqua_a2     intex                 aqua_a2
# 1355  1355     videocon_infinium_z51_nova+  videocon      infinium_z51_nova+
# 1356  1356                   intex_aqua_y4     intex                 aqua_y4
# 1357  1357                 iball_andi4_b20     iball               andi4_b20
# 1358  1358             iball_andi_avonte_5     iball           andi_avonte_5
#
# ...

# %%
df = df.drop(['m'], axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1359 entries, 0 to 1358
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   name                    1359 non-null   object
#  1   brand                   1359 non-null   object
#  2   model                   1359 non-null   object
#  3   battery_capacity_(mah)  1359 non-null   int64
#  4   screen_size_(inches)    1359 non-null   float64
#  5   touchscreen             1359 non-null   object
#  6   resolution_x            1359 non-null   int64
#  7   resolution_y            1359 non-null   int64
#  8   processor               1359 non-null   int64
#  9   ram_(mb)                1359 non-null   int64
#  10  internal_storage_(gb)   1359 non-null   float64
#  11  rear_camera             1359 non-null   float64
#  12  front_camera            1359 non-null   float64
#  13  operating_system        1359 non-null   object
# ...

# %%
x = df.drop(['price', 'name', 'brand', 'model', 'touchscreen', 'operating_system', 'wi-fi', 'bluetooth', 'gps', '3g', '4g/_lte'], axis=1)
y = df['price']
my_model = LinearRegression()
my_model.fit(x, y)
my_model.score(x, y)
# Out:
# 0.5204709809325523

# %%
plt.figure(figsize=((15, 6)))
sns.heatmap(df.corr(), annot=True)
# Out:
# C:\Users\Abd-el-Rahman\AppData\Local\Temp\ipykernel_11684\3762546680.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)
# <Axes: >

# %%
df = df.drop(['resolution_x', 'ram_(mb)', 'number_of_sims'], axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1359 entries, 0 to 1358
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   name                    1359 non-null   object
#  1   brand                   1359 non-null   object
#  2   model                   1359 non-null   object
#  3   battery_capacity_(mah)  1359 non-null   int64
#  4   screen_size_(inches)    1359 non-null   float64
#  5   touchscreen             1359 non-null   object
#  6   resolution_y            1359 non-null   int64
#  7   processor               1359 non-null   int64
#  8   internal_storage_(gb)   1359 non-null   float64
#  9   rear_camera             1359 non-null   float64
#  10  front_camera            1359 non-null   float64
#  11  operating_system        1359 non-null   object
#  12  wi-fi                   1359 non-null   object
#  13  bluetooth               1359 non-null   object
# ...

# %%
plt.figure(figsize=((15, 6)))
sns.heatmap(df.corr(), annot=True)
# Out:
# C:\Users\Abd-el-Rahman\AppData\Local\Temp\ipykernel_11684\3762546680.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)
# <Axes: >

# %%
df.describe()
# Out:
#        battery_capacity_(mah)  screen_size_(inches)  resolution_y  \
# count             1359.000000           1359.000000   1359.000000
# mean              2938.489330              5.291310   1490.777778
# std                873.514133              0.671357    557.780120
# min               1010.000000              2.400000    320.000000
# 25%               2300.000000              5.000000   1280.000000
# 50%               3000.000000              5.200000   1280.000000
# 75%               3500.000000              5.700000   1920.000000
# max               6000.000000              7.300000   3840.000000
#
#          processor  internal_storage_(gb)  rear_camera  front_camera  \
# count  1359.000000            1359.000000  1359.000000   1359.000000
# mean      5.551141              30.654864    12.070199      7.037969
# std       2.196562              36.950241     8.948337      6.295448
# min       1.000000               0.064000     0.000000      0.000000
# ...

# %%
plt.figure(figsize=((15, 6)))
sns.histplot(df['price'], kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
df = df[df['price']<75000]
plt.figure(figsize=((15, 6)))
sns.histplot(df['price'], kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
df.describe()
# Out:
#        battery_capacity_(mah)  screen_size_(inches)  resolution_y  \
# count             1350.000000           1350.000000   1350.000000
# mean              2931.157037              5.283037   1482.825926
# std                870.506078              0.664900    550.386820
# min               1010.000000              2.400000    320.000000
# 25%               2300.000000              5.000000   1280.000000
# 50%               2966.000000              5.200000   1280.000000
# 75%               3500.000000              5.650000   1920.000000
# max               6000.000000              7.000000   3840.000000
#
#          processor  internal_storage_(gb)  rear_camera  front_camera  \
# count  1350.000000            1350.000000  1350.000000   1350.000000
# mean      5.540741              29.721452    11.970667      6.979704
# std       2.197319              33.304257     8.553816      6.210393
# min       1.000000               0.064000     0.000000      0.000000
# ...

# %%
plt.figure(figsize=((15, 6)))
sns.scatterplot(x=df['battery_capacity_(mah)'], y=df['price'])
# Out:
# <Axes: xlabel='battery_capacity_(mah)', ylabel='price'>

# %%
df['battery_capacity_(mah)'] = np.where(df['battery_capacity_(mah)']>5000, 5000, df['battery_capacity_(mah)'])
plt.figure(figsize=((15, 6)))
sns.scatterplot(x=df['battery_capacity_(mah)'], y=df['price'])
# Out:
# <Axes: xlabel='battery_capacity_(mah)', ylabel='price'>

# %%
df.describe()
# Out:
#        battery_capacity_(mah)  screen_size_(inches)  resolution_y  \
# count             1350.000000           1350.000000   1350.000000
# mean              2928.623704              5.283037   1482.825926
# std                863.125835              0.664900    550.386820
# min               1010.000000              2.400000    320.000000
# 25%               2300.000000              5.000000   1280.000000
# 50%               2966.000000              5.200000   1280.000000
# 75%               3500.000000              5.650000   1920.000000
# max               5000.000000              7.000000   3840.000000
#
#          processor  internal_storage_(gb)  rear_camera  front_camera  \
# count  1350.000000            1350.000000  1350.000000   1350.000000
# mean      5.540741              29.721452    11.970667      6.979704
# std       2.197319              33.304257     8.553816      6.210393
# min       1.000000               0.064000     0.000000      0.000000
# ...

# %%
plt.figure(figsize=((15, 6)))
sns.scatterplot(x=df['resolution_y'], y=df['price'])
# Out:
# <Axes: xlabel='resolution_y', ylabel='price'>

# %%
df['resolution_y'] = np.where(df['resolution_y']>3000, 3000, df['resolution_y'])
plt.figure(figsize=((15, 6)))
sns.scatterplot(x=df['resolution_y'], y=df['price'])
# Out:
# <Axes: xlabel='resolution_y', ylabel='price'>

# %%
df.describe()
# Out:
#        battery_capacity_(mah)  screen_size_(inches)  resolution_y  \
# count             1350.000000           1350.000000   1350.000000
# mean              2928.623704              5.283037   1480.662963
# std                863.125835              0.664900    543.298066
# min               1010.000000              2.400000    320.000000
# 25%               2300.000000              5.000000   1280.000000
# 50%               2966.000000              5.200000   1280.000000
# 75%               3500.000000              5.650000   1920.000000
# max               5000.000000              7.000000   3000.000000
#
#          processor  internal_storage_(gb)  rear_camera  front_camera  \
# count  1350.000000            1350.000000  1350.000000   1350.000000
# mean      5.540741              29.721452    11.970667      6.979704
# std       2.197319              33.304257     8.553816      6.210393
# min       1.000000               0.064000     0.000000      0.000000
# ...

# %%
plt.figure(figsize=((15, 6)))
sns.barplot(x=df['internal_storage_(gb)'], y=df['price'])
# Out:
# <Axes: xlabel='internal_storage_(gb)', ylabel='price'>

# %%
df['internal_storage_(gb)'] = np.where(df['internal_storage_(gb)']>128, 128, df['internal_storage_(gb)'])
plt.figure(figsize=((15, 6)))
sns.scatterplot(x=df['internal_storage_(gb)'], y=df['price'])
# Out:
# <Axes: xlabel='internal_storage_(gb)', ylabel='price'>

# %%
df.describe()
# Out:
#        battery_capacity_(mah)  screen_size_(inches)  resolution_y  \
# count             1350.000000           1350.000000   1350.000000
# mean              2928.623704              5.283037   1480.662963
# std                863.125835              0.664900    543.298066
# min               1010.000000              2.400000    320.000000
# 25%               2300.000000              5.000000   1280.000000
# 50%               2966.000000              5.200000   1280.000000
# 75%               3500.000000              5.650000   1920.000000
# max               5000.000000              7.000000   3000.000000
#
#          processor  internal_storage_(gb)  rear_camera  front_camera  \
# count  1350.000000            1350.000000  1350.000000   1350.000000
# mean      5.540741              29.057748    11.970667      6.979704
# std       2.197319              29.885837     8.553816      6.210393
# min       1.000000               0.064000     0.000000      0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1350 entries, 0 to 1358
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   name                    1350 non-null   object
#  1   brand                   1350 non-null   object
#  2   model                   1350 non-null   object
#  3   battery_capacity_(mah)  1350 non-null   int64
#  4   screen_size_(inches)    1350 non-null   float64
#  5   touchscreen             1350 non-null   object
#  6   resolution_y            1350 non-null   int64
#  7   processor               1350 non-null   int64
#  8   internal_storage_(gb)   1350 non-null   float64
#  9   rear_camera             1350 non-null   float64
#  10  front_camera            1350 non-null   float64
#  11  operating_system        1350 non-null   object
#  12  wi-fi                   1350 non-null   object
#  13  bluetooth               1350 non-null   object
# ...

# %%
df['4g/_lte'].nunique()
# Out:
# 2

# %%
df = df.drop(['name', 'model'], axis=1)
df = pd.get_dummies(df, columns=['brand', 'touchscreen', 'operating_system', 'wi-fi', 'bluetooth', 'gps', '3g', '4g/_lte'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1350 entries, 0 to 1358
# Columns: 102 entries, battery_capacity_(mah) to 4g/_lte_yes
# dtypes: float64(4), int64(4), uint8(94)
# memory usage: 218.8 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1350 entries, 0 to 1358
# Columns: 102 entries, battery_capacity_(mah) to 4g/_lte_yes
# dtypes: float64(4), int64(4), uint8(94)
# memory usage: 218.8 KB

# %%
x = df.drop(['price'], axis=1)
y = df['price']
my_model = LinearRegression()
my_model.fit(x, y)
my_model.score(x, y)
# Out:
# 0.6463653282031938
